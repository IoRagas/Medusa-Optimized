# %% [markdown]
# # 🐍 Medusa Speculative Decoding — Colab Benchmark
#
# This notebook benchmarks **Medusa** speculative decoding vs standard autoregressive generation.
#
# **Requirements:**
# - **GPU Runtime**: Go to `Runtime → Change runtime type → T4 GPU` (free tier works!)
# - The T4 has 15GB VRAM — enough for the 7B model in fp16
#
# **What this does:**
# 1. Clones the repo & installs dependencies
# 2. Runs the benchmark in pure fp16 (no quantization needed)
# 3. Shows speedup: Standard vs Medusa generation

# %% [markdown]
# ## Step 1: Clone Repo & Install

# %%
# Clone your repo (replace with your actual repo URL)
# !git clone https://github.com/YOUR_USERNAME/Medusa.git /content/Medusa 2>/dev/null || echo 'Repo already cloned'
# %cd /content/Medusa

# Install the package + dependencies
# !pip install -e . -q

# %% [markdown]
# ## Step 2: Verify GPU

# %%
import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')
    vram = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f'VRAM: {vram:.1f} GB')
else:
    print('❌ No GPU detected! Go to Runtime → Change runtime type → T4 GPU')

# %% [markdown]
# ## Step 3: Run Benchmark (fp16)

# %%
# Run the benchmark in pure fp16 mode — the simple 16-bit command!
# !python benchmark_medusa.py

# %% [markdown]
# ## (Optional) Run with 8-bit quantization
# If you want to save VRAM or compare quantized performance:

# %%
# Optional: Install bitsandbytes for quantized modes
# !pip install bitsandbytes -q
# !python benchmark_medusa.py --load-in-8bit

# %% [markdown]
# ## (Optional) Interactive Chat

# %%
# Interactive chat with Medusa (run in terminal-like mode)
# !python -m medusa.inference.cli --model FasterDecoding/medusa-vicuna-7b-v1.3
